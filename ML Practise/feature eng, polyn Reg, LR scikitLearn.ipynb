# %% [markdown]
# **feature engineering and Polynomial regression**

# %% [markdown]
# **the snapshots are from coursera Machine Learning Course:**

# %% [markdown]
# ![24.png](attachment:66775ae1-247b-417f-916f-333cc51e1c2f.png)

# %% [markdown]
# **Linear Regression using Scikit-Learn**

# %% [markdown]
# ![2024-08-18 02 12 15.png](attachment:31a8449f-df0e-4030-b5d3-4ca7d6bcc0fe.png)
